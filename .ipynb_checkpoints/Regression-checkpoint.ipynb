# %% [markdown]
# # Usable Code

# %%
import pickle

import numpy as np
import pandas as pd

# %%
with open('game_df.pickle','rb') as read_file:
    game_df = pickle.load(read_file)
    
game_df
# Out:
#       total  tot_1st  tot_rush_att  tot_rush_yds  tot_rush_tds  tot_comp  \
# 0        76       54            48           184             2        59
# 1        44       48            58           390             2        32
# 2        42       37            47           236             1        39
# 3        30       33            60           206             1        38
# 4        41       41            57           231             2        33
# ...     ...      ...           ...           ...           ...       ...
# 2398     82       52            42           212             3        54
# 2399     51       45            54           219             4        37
# 2400     59       47            50           197             3        45
# 2401     57       40            58           347             5        37
# 2402     51       47            51           270             3        46
#
#       tot_att  tot_pass_yds  total_pass_tds  total_int  ...  tot_third_per  \
# ...
